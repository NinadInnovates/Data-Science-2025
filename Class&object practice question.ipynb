# %%
class Dog :
  sound = "bark"
dog1 = Dog()
print(dog1.sound)
# Out:
# bark

# %%
class car :
  def __init__(self , name , brand):
    self.name= name
    self.brand = brand
car1 = car("ford", "mustang")
car2 = car("hundai", "venu")
print(car1.name , car1.brand)
print(car2.name , car2.brand)
# Out:
# ford mustang
# hundai venu

# %%
class Person :
    def __init__(self , name ,age):
      self.name = name
      self.age = age
    def intro(self):
      print(f"my name is {self.name} and I am {self.age} years old")
person1 = Person("ninad" ,22)
person1.intro()
# Out:
# my name is ninad and I am 22 years old

# %%
class Dog :

  def __init__(self , name , age):
    self.name = name
    self.age = age
  def Bark(self):
    print(f'{self.name} is barking !')
dog1 = Dog("tom", 2)
dog1.Bark()
# Out:
# tom is barking !

# %%
class cat :
  def __init__(self , name, color):
    self.name = name
    self.color = color

  def meow(self):
    print ("MEOW !")
cat1 = cat("tom","white")
print(cat1.name ,cat1.color)
cat1.meow()
# Out:
# tom white
# MEOW !

# %%
# Understanding __init__ Method
# A constructor is a special method within a class that automatically initializes a new object when it is created.
# The constructor's main role is to assign values to the data members of the class.

# %%
class person:
  def __init__(self,name,age):
   self.name = name
   self.age =age
person1 = person("ninad ", 22)
print(person1.name ,person1.age)
# Out:
# ninad  22

# %%
class product :

  total_product = 0

  def __init__(self,name, price):
    self.name= name
    self.price = price
    product.total_product +=1
product1 = product("mobile" , 10000)
product2 = product("lapton" ,40000)
print(product1.name ,product1.price)
print(product2.name , product2.price)
print(product.total_product)
# Out:
# mobile 10000
# lapton 40000
# 2

# %%
# 1. Basic Class and Object

# %%
class Dog:
    def __init__(self, name, breed):
        self.name = name
        self.breed = breed

    def bark(self):
        print("Woof!")

dog1 = Dog("Buddy", "Golden Retriever")
dog2 = Dog("Lucy", "Poodle")

print(dog1.name)  # Output: Buddy
print(dog2.breed) # Output: Poodle
dog1.bark()      # Output: Woof!
# Out:
# Buddy
# Poodle
# Woof!

# %%
# 2. Class with Class Variable

# %%
class Car:
    wheels = 4  # Class variable

    def __init__(self, model, color):
        self.model = model
        self.color = color

car1 = Car("Sedan", "Red")
car2 = Car("SUV", "Blue")

print(car1.wheels)  # Output: 4
print(car2.model)  # Output: SUV
# Out:
# 4
# SUV

# %%
# 3. Class with Methods

# %%
class Rectangle :

  def __init__(self , length , width):
    self.length = length
    self.width = width
  def area(self):
   return self.length + self.width

   def perimeter(self):
    return 2 * (self.length + self.width)

rec =Rectangle(3,6)
print(rec.area())
# Out:
# 9

# %%
# 4. Class with Inheritance
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print("Generic animal sound")

class Cat(Animal):
    def __init__(self, name, breed):
        super().__init__(name)
        self.breed = breed

    def speak(self):
        print("Meow!")

# Creating objects
animal = Animal("Generic")
cat = Cat("Whiskers", "Siamese")

# Calling methods
animal.speak() # Output: Generic animal sound
cat.speak()    # Output: Meow!
print(cat.name) # Output: Whiskers
# Out:
# Generic animal sound
# Meow!
# Whiskers

# %%
# 4. Class with Methods Performing Operations

class calculator :
  def add(self ,a,b):
    return a+b
calc= calculator()
print(calc.add(2,34))
# Out:
# 36

# %%
# 5. Class with Default Values
class Dog:
    def __init__(self, breed="Labrador"):
        self.breed = breed

    def show(self):
        print("Breed:", self.breed)

d = Dog()
d.show()
# Out:
# Breed: Labrador

# %%
# 6 .Class with Update Method
class Account:
    def __init__(self, balance):
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def show_balance(self):
        print("Balance:", self.balance)

acc = Account(1000)
acc.deposit(500)
acc.show_balance()
# Out:
# Balance: 1500

# %%
#Class with __str__() Method

class Book :

  def __init__(self,name , author):
    self.name=name
    self.auther = author

  def __str__(self):
    return f" {self.name} by {self.auther}"

book1 = Book("python","ninad")
print(book1)
# Out:
#  python by ninad

# %%
class Bank :

  def __init__(self,balance):
    self.balance = balance
  def deposite(self,amount):
    self.amount = amount
    self.balance += amount # (balance = balance + amount) 0+1000 =1000
    #1000+500 =1500
  def show_balance(self):
    print(f"balance : {self.balance}")

acc = Bank(1000)
acc.deposite(500)
acc.show_balance()
# Out:
# balance : 1500

# %%
# 1. Basic Class Creation** **Problem**: Create a class `Person` with attributes: `name`, `age`, and `gender`. Add a method `introduce()` that prints a sentence introducing the person.
class Person:
    def __init__(self, name, age, gender):
        self.name = name
        self.age = age
        self.gender = gender

    def introduce(self):
        print(f"Hi, I'm {self.name}. I'm {self.age} years old and I am {self.gender}.")

p1 = Person("Alice", 25, "female")
p1.introduce()
# Out:
# Hi, I'm Alice. I'm 25 years old and I am female.

# %%
# 2. Bank Account Simulator** **Problem**:Create a class `BankAccount` with attributes `account_number`, `owner`, and `balance` (default: 0). Add methods to `deposit()`, `withdraw()`, and `display_balance()`.
class BankAccount :
  def __init__(self ,account_number, owner, balance=0):
    self.account_number = account_number
    self.owner = owner
    self.balance = balance

  def deposit(self,amount):
    self.balance += amount

  def withdraw(self, amount):
    if self.balance >= amount:
      self.balance -= amount
      return amount
    else:
      print("Insufficient funds")
      return 0

  def display_balance(self):
    print(f"balance : {self.balance}")

acc = BankAccount(123456789,"ninad",1000)
acc.deposit(500)
acc.display_balance()
# Out:
# balance : 1500
