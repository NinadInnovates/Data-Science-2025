# %%
name = "Ninad shashank pakhode"
print(name[0])
# Out:
# N

# %%
print(name[-1])
# Out:
# e

# %%
print(name[1 :13])
# Out:
# inad shashan

# %%
a =5
b=10
print(f"addition of {a} + {b} is {a+b}")
# Out:
# addition of 5 + 10 is 15

# %%
num = 3.14678

# %%
print(f"the round of number is :{num:.3f}")
# Out:
# the round of number is :3.147

# %%
text = "Python"

# %%
for index , char in enumerate(text):
 print(f"index:{index}, character: {char}")
# Out:
# index:0, character: P
# index:1, character: y
# index:2, character: t
# index:3, character: h
# index:4, character: o
# index:5, character: n

# %%
text = "python"
index = 0
while index < len(text):
  print(text[index])
  index=+1
# Out:
# Streaming output truncated to the last 5000 lines.
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# y
# ...
